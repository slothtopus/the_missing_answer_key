# %% [markdown]
# # Study Question 3.8.1
#
# a)
# $$
# \begin{align}
# W_{1} \perp W_{2} \implies R_{W_{1}W_{2}} = 0\\
# Z_{1} \perp Z_{2} \implies R_{Z_{1}Z_{2}} = 0\\
# W_{1} \perp W_{3} \mid X \implies R_{W_{1}W_{3}\ X} = 0
# \end{align}
# $$
#
# b)
# $$X \perp Y \mid W_{3},Z_{3} \implies R_{XY\ W_{3}Z_{3}} = 0$$
#
# c)
#
# $$\begin{align}
# a_{1}:\ &W_{1} = a_{1}Z_{1}\\
# \\
# a_{3}:\ &Z_{3} = a_{3}Z_{1}\\
# \\
# c_{2}:\ &W_{2} = c_{2}Z_{2}\\
# \\
# t_{1}:\ &X = t_{1}W_{1} + r_{1}Z_{1}\\
# &X = t_{1}W_{1} + r_{1}Z_{3}\\
# \\
# t_{2}:\ &X = t_{2}Z_{3} + r_{1}Z_{1}\\
# &X = t_{2}Z_{3} + r_{1}W_{1}\\
# \\
# b:\ &Y = bZ_{3} + r_{1}Z_{2} + r_{2}W_{3}\\
# &Y = bZ_{3} + r_{1}W_{2} + r_{2}W_{3}\\
# &Y = bZ_{3} + r_{1}W_{2} + r_{2}X\\
# &Y = bZ_{3} + r_{1}X + r_{2}Z_{2}\\
# \\
# c:\ &Y = cW_{2} + r_{1}Z_{2}\\
# &Y = cW_{2} + r_{1}W_{1} + r_{2}Z_{3}\\
# &Y = cW_{2} + r_{1}W_{3} + r_{2}Z_{3}\\
# &Y = cW_{2} + r_{1}X + r_{2}Z_{3}\\
# &Y = cW_{2} + r_{1}Z_{1} + r_{2}Z_{3}\\
# \\
# c_{3}:\ &W_{3} = c_{3}X\\
# \\
# a:\ &Y = aW_{3} + r_{1}X\\
# &Y = aW_{3} + r_{1}W_{1} + r_{2}Z_{3}\\
# &Y = aW_{3} + r_{1}W_{2} + r_{2}Z_{3}\\
# &Y = aW_{3} + r_{1}Z_{1} + r_{2}Z_{3}\\
# &Y = aW_{3} + r_{1}Z_{2} + r_{2}Z_{3}\\
# \end{align}$$
#
# d) We can estimate identify the parameters $c_{3}$ and $a$. Total effect cannot be estimated because there is a backdoor path $X \leftarrow Z_{3} \rightarrow Y$ that is not blocked.
#
# e)
# $$Z_{1} = r_{1}Z_{2} + r_{2}Z_{3} + r_{3}W_{1} + r_{4}W_{2} + r_{5}W_{3} + r_{6}X + r_{7}Y\\
# r_{4} = r_{5} = r_{6} = r_{7} = 0$$
#
# f)<br>
# 1. $a_{3}$ is invariant if $W_{1}$ is added to $Z_{3} = a_{3}Z_{1}$
# 2. $b_{3}$ is invariant if $W_{2}$ is added to $Z_{3} = b_{3}Z_{2}$
# 3. $c_{2}$ is invariant if $Z_{1}$ is added to $W_{2} = c_{2}Z_{2}$
# 4. $c_{3}$ is invariant if $W_{1}$ is added to $W_{3} = c_{3}X$
# 5. $a$ is invariant if $W_{2}$ is added to $Y = aW_{3} + r_{1}X$
#
# g) We calculate two regressions:
# $$
# Z_{3} = r_{1}Z_{1}\\
# Y = r_{2}Z_{1} + r_{3}W_{1}
# $$
#
# $r_{1} = a_{3}$ and $r_{2} = a_{3}b$, therefore $b = r_{2} / r_{1}$
