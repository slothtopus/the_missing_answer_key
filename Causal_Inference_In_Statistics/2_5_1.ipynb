# %% [markdown]
# # Study Question 2.5.1
#
# a) We first list the v-structures in the graph. Equivalent graphs must also only have these v-structures.
#
# $W \rightarrow Y \leftarrow Z_{3}$<br>
# $W \rightarrow Y \leftarrow Z_{2}$<br>
# $Z_{1} \rightarrow Z_{3} \leftarrow Z_{2}$
#
# This leaves the following arrows that could be changed.
#
# $Z_{1} \rightarrow X$<br>
# $Z_{3} \rightarrow X$<br>
# $X \rightarrow W$<br>
#
# Flipping $X \rightarrow W$ would introduce a new v-structure ($W \rightarrow X \leftarrow Z_{3}$).
#
# Flipping $Z_{1} \rightarrow X$ would introduce a cycle ($X \rightarrow Z_{1} \rightarrow Z_{3} \rightarrow X$).
#
# Flipping $Z_{3} \rightarrow X$ would also introduce a new v-structure ($X \rightarrow Z_{3} \leftarrow Z_{2}$).
#
# Therefore, no arrows can be reversed in the model to create an equivalent model.
#
# b) Since the equivalence class only contains one graph, there is only one observationally equivalent graph.
#
# c) If we assume that for each test of directionality for a given arrow, we already know the directionality of all other arrows (the question isn't clear), then for each arrow we can look for an independence that exists for one direction of the arrow but does not for the opposite direction. Here we use $A \perp B \mid C$ to mean $A$ is independent to $B$ given $C$.
#
# $X \rightarrow W \iff Z_{3} \perp W \mid X$<br>
# $W \leftarrow Y \iff Z_{3} \perp W \mid Y$<br>
# $Z_{1} \rightarrow X$ because otherwise we would have a cycle<br>
# $Z_{3} \leftarrow X \iff X \perp Z_{2}$<br>
# $Z_{1} \rightarrow Z_{3} \iff Z_{1} \perp Z_{2}$<br>
# $Z_{2} \rightarrow Z_{3} \iff Z_{1} \perp Z_{2}$<br>
# $Z_{3} \rightarrow Y$ because otherwise we would have a cycle<br>
# $Z_{2} \rightarrow Y$ because otherwise we would have a cycle<br>
#
# d) From the graph we know that $Y \perp X \mid W, Z_{1}, Z_{3}$.
#
# Therefore, in the regression $y = r_{x}x + r_{w}w + r_{1}z_{1} + r_{3}z_{3}$, this implies that $r_{x}$ should be zero. If it isn't, then the model is wrong.
#
# e) From the graph we know that $Z_{3} \perp W \mid X$.
#
# Therefore, in the regression $z_{3} = r_{x}x + r_{w}w$, this implies that $r_{w}$ should be zero. If it isn't, then the model is wrong.
#
# f) Without $X$ we cannot build an expression for $Z_{3}$ because $W$ is the only variable that isn't adjacent to $Z_{3}$ and $X$ is the only variable that d-separates the two.
#
# g) For each pair of non-adjacent variables we can find the d-separating sets and use these to build our regression equations to test.
#
# |Pair|Condition on|Regression equation|Zero coefficient
# |:-:|:-:|:-:|:-:|
# $$(W,Z_{1})$$ | $$ X $$ | $$w = r_{1}z_{1} + r_{x}x$$ | $$r_{1}$$
# $$(W,Z_{2})$$ | $$ X $$ | $$w = r_{2}z_{2} + r_{x}x$$ | $$r_{2}$$
# $$(W,Z_{3})$$ | $$ X $$ | $$w = r_{3}z_{3} + r_{x}x$$ | $$r_{3}$$
# $$(X,Y)$$ | $$W, Z_{1}, Z_{3}$$ | $$x = r_{w}w + r_{y}y + r_{1}z_{1} + r_{3}z_{3}$$| $$r_{y}$$
# $$(X,Y)$$ | $$W, Z_{2}, Z_{3}$$ | $$x = r_{w}w + r_{y}y + r_{2}z_{2} + r_{3}z_{3}$$| $$r_{y}$$
# $$(X,Z_{2})$$ | $$ Z_{1}, Z_{3} $$ | $$x = r_{1}z_{1} + r_{2}z_{2} + r_{3}z_{3}$$| $$r_{2}$$
# $$(Y,Z_{1})$$ | $$W, Z_{2}, Z_{3}$$ | $$y = r_{w}w + r_{1}z_{1} + r_{2}z_{2} + r_{3}z_{3}$$| $$r_{1}$$
# $$(Y,Z_{1})$$ | $$X, Z_{2}, Z_{3}$$ | $$y = r_{x}x + r_{1}z_{1} + r_{2}z_{2} + r_{3}z_{3}$$| $$r_{1}$$
# $$(Z_{1},Z_{2})$$ | $$ \emptyset $$ | $$z_{1} = r_{2}z_{2}$$| $$r_{2}$$
